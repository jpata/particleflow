# %%
# %matplotlib inline
import bz2
import pickle
import pandas
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pickle.load(open("../pfntuple_1.pkl", "rb"))

# %%
iev = 1
Xelem = pandas.DataFrame(data[iev]["Xelem"])
ycand = pandas.DataFrame(data[iev]["ycand"])
ygen = pandas.DataFrame(data[iev]["ygen"])

# %%
Xelem

# %%
ycand

# %%
ygen

# %%
import plotly.graph_objects as go

# %%
import plotly

# %%
go.Scatter3d?

# %%
eta_range = 1000
radius_mult = 2000

trk_x = []
trk_y = []
trk_z = []
for irow, row in Xelem[Xelem["typ"]==1].iterrows():
    trk_x += [0, radius_mult*np.sin(row["phi"])]
    trk_z += [0, radius_mult*np.cos(row["phi"])]
    trk_y += [0, eta_range*row["eta"]]
    if row["phi_ecal"] != 0:
        trk_x += [1.5*radius_mult*np.sin(row["phi_ecal"])]
        trk_z += [1.5*radius_mult*np.cos(row["phi_ecal"])]
        trk_y += [eta_range*row["eta_ecal"]]
    if row["phi_hcal"] != 0:
        trk_x += [2*radius_mult*np.sin(row["phi_hcal"])]
        trk_z += [2*radius_mult*np.cos(row["phi_hcal"])]
        trk_y += [eta_range*row["eta_hcal"]]
        
points_trk = go.Scatter3d(
    x=trk_x,
    z=trk_z,
    y=trk_y,
    mode="lines",
    line=dict(color='rgba(10, 10, 10, 0.05)'),
    name="Tracks",
    hoverinfo="skip"
)

msk = Xelem["typ"]==2
points_ps1 = go.Scatter3d(
    x=1*radius_mult*np.cos(Xelem[msk]["phi"].values),
    z=1*radius_mult*np.sin(Xelem[msk]["phi"].values),
    y=eta_range*Xelem[msk]["eta"].values,
    mode="markers",
    marker={
        "symbol": "square",
        "opacity": 0.8,
        "size": 1000*Xelem[msk]["e"],
        #"size": 2.0
    },
    name="PS1",
    hovertemplate="<b>%{hovertext}</b>",
    hovertext=["E={:.2f}".format(x["e"]) for _, x in Xelem[msk].iterrows()],
)

msk = Xelem["typ"]==3
points_ps2 = go.Scatter3d(
    x=1*radius_mult*np.cos(Xelem[msk]["phi"].values),
    z=1*radius_mult*np.sin(Xelem[msk]["phi"].values),
    y=eta_range*Xelem[msk]["eta"].values,
    mode="markers",
    marker={
        "symbol": "square",
        "opacity": 0.8,
        "size": 1000*Xelem[msk]["e"],
    },
    name="PS2",
    hovertemplate="<b>%{hovertext}</b>",
    hovertext=["E={:.2f}".format(x["e"]) for _, x in Xelem[msk].iterrows()],
)

msk = Xelem["typ"]==4
points_ecal = go.Scatter3d(
    x=1.5*radius_mult*np.cos(Xelem[msk]["phi"].values),
    z=1.5*radius_mult*np.sin(Xelem[msk]["phi"].values),
    y=eta_range*Xelem[msk]["eta"].values,
    mode="markers",
    marker={
        "symbol": "square",
        "opacity": 0.8,
        "size": 10*np.log10(Xelem[msk]["e"]+1.0),
        #"size": 2.0
    },
    name="ECAL",
    hovertemplate="<b>%{hovertext}</b>",
    hovertext=["E={:.2f}".format(x["e"]) for _, x in Xelem[msk].iterrows()],
)

msk = Xelem["typ"]==5
points_hcal = go.Scatter3d(
    x=2*radius_mult*np.cos(Xelem[msk]["phi"].values),
    z=2*radius_mult*np.sin(Xelem[msk]["phi"].values),
    y=eta_range*Xelem[msk]["eta"].values,
    mode="markers",
    marker={
        "symbol": "square",
        "opacity": 0.8,
        "size": 5*np.log10(Xelem[msk]["e"]+1.0),
        #"size": 2.0
    },
    name="HCAL",
    hovertemplate="<b>%{hovertext}</b>",
    hovertext=["E={:.2f}".format(x["e"]) for _, x in Xelem[msk].iterrows()],
)


msk = Xelem["typ"]==8
points_hfem = go.Scatter3d(
    x=2*radius_mult*np.cos(Xelem[msk]["phi"].values),
    z=2*radius_mult*np.sin(Xelem[msk]["phi"].values),
    y=eta_range*Xelem[msk]["eta"].values,
    mode="markers",
    marker={
        "symbol": "square",
        "opacity": 0.8,
        "size": 5*np.log10(Xelem[msk]["e"]+1.0),
        #"size": 2.0
    },
    name="HFEM",
    hovertemplate="<b>%{hovertext}</b>",
    hovertext=["E={:.2f}".format(x["e"]) for _, x in Xelem[msk].iterrows()],
)

msk = Xelem["typ"]==9
points_hfhad = go.Scatter3d(
    x=2*radius_mult*np.cos(Xelem[msk]["phi"].values),
    z=2*radius_mult*np.sin(Xelem[msk]["phi"].values),
    y=eta_range*Xelem[msk]["eta"].values,
    mode="markers",
    marker={
        "symbol": "square",
        "opacity": 0.8,
        "size": 5*np.log10(Xelem[msk]["e"]+1.0),
        #"size": 2.0
    },
    name="HFHAD",
    hovertemplate="<b>%{hovertext}</b>",
    hovertext=["E={:.2f}".format(x["e"]) for _, x in Xelem[msk].iterrows()],
)

msk = Xelem["typ"]==10
points_sc = go.Scatter3d(
    x=2*radius_mult*np.cos(Xelem[msk]["phi"].values),
    z=2*radius_mult*np.sin(Xelem[msk]["phi"].values),
    y=eta_range*Xelem[msk]["eta"].values,
    mode="markers",
    marker={
        "symbol": "square",
        "opacity": 0.8,
        "size": 5*np.log10(Xelem[msk]["e"]+1.0),
        #"size": 2.0
    },
    name="SC",
    hovertemplate="<b>%{hovertext}</b>",
    hovertext=["E={:.2f}".format(x["e"]) for _, x in Xelem[msk].iterrows()],
)

msk = Xelem["typ"]==11
points_ho = go.Scatter3d(
    x=2.1*radius_mult*np.cos(Xelem[msk]["phi"].values),
    z=2.1*radius_mult*np.sin(Xelem[msk]["phi"].values),
    y=eta_range*Xelem[msk]["eta"].values,
    mode="markers",
    marker={
        "symbol": "square",
        "opacity": 0.8,
        "size": 5*np.log10(Xelem[msk]["e"]+1.0),
        #"size": 2.0
    },
    name="HO",
    hovertemplate="<b>%{hovertext}</b>",
    hovertext=["E={:.2f}".format(x["e"]) for _, x in Xelem[msk].iterrows()],
)

msk = ycand["typ"]!=0
points_cand = go.Scatter3d(
    x=2.2*radius_mult*ycand[msk]["cos_phi"].values,
    z=2.2*radius_mult*ycand[msk]["sin_phi"].values,
    y=eta_range*ycand[msk]["eta"].values,
    mode="markers",
    marker={
        "symbol": "x",
        "opacity": 0.8,
        "color": 'rgba(0, 0, 0, 0.8)',
        #"size": 2.0
        "size": 5*np.log10(ycand[msk]["e"]+5.0),
    },
    hovertemplate="<b>%{hovertext}</b>",
    hovertext=["{}<br>E={:.2f}".format(int(x["typ"]), x["e"]) for _, x in ycand[msk].iterrows()],
    name="PFCand"
)


msk = ygen["typ"]!=0
points_gen = go.Scatter3d(
    x=2.5*radius_mult*ygen[msk]["cos_phi"].values,
    z=2.5*radius_mult*ygen[msk]["sin_phi"].values,
    y=eta_range*ygen[msk]["eta"].values,
    mode="markers",
    marker={
        "symbol": "circle",
        "opacity": 0.8,
        "color": 'rgba(50, 50, 50, 0.4)',
        #"size": 2.0
        "size": 5*np.log10(ygen[msk]["e"]+5),
    },
    hovertemplate="<b>%{hovertext}</b>",
    hovertext=["{}<br>E={:.2f}".format(int(x["typ"]), x["e"]) for _, x in ygen[msk].iterrows()],
    name="Gen"
)


fig = go.Figure(data=[
    points_trk,
    points_ps1, points_ps2,
    points_ecal, points_hcal,
    points_hfem, points_hfhad,
    points_sc, points_ho,
    points_cand, points_gen])

fig.update_layout(
    autosize=True,
    #width=800,
    #height=1200,
#     margin=go.layout.Margin(
#         l=50,
#         r=0,
#         b=0,
#         t=50,
#     ),
    scene_camera={
        "eye": dict(x=0.8, y=0.8, z=0.8),
    },
    scene={
        "xaxis": dict(nticks=1, range=[-5000,5000], showaxeslabels=False, showticklabels=False, showgrid=False, visible=False),
        "yaxis": dict(nticks=1, range=[-5000,5000], showaxeslabels=False, showticklabels=False, showgrid=False, visible=False),
        "zaxis": dict(nticks=1, range=[-5000,5000], showaxeslabels=False, showticklabels=False, showgrid=False, visible=False),
    }
)
fig.update_layout(legend= {'itemsizing': 'constant'})
fig.show()

# %%
s = fig.to_html(default_width="1200px", default_height="800px")
with open("plot.html", "w") as fi:
    fi.write(s)

# %%
for node in g.nodes:
    if node[0] == "elem":
        if g.nodes[node]["typ"] == 8:
            print("node={node} typ={typ} e={e:.2f} eta={eta:.2f}".format(
                node=node,
                typ=g.nodes[node]["typ"],
                e=g.nodes[node]["e"],
                eta=g.nodes[node]["eta"]
            ))
            for pred in g.predecessors(node):
                print("  pred={pred} typ={typ} e={e:.2f} eta={eta:.2f} w={w:.2f}".format(
                      pred=pred,
                      typ=g.nodes[pred]["typ"],
                      e=g.nodes[pred]["e"],
                      eta=g.nodes[pred]["eta"],
                      w=g.edges[(pred, node)]["weight"]))
            for suc in g.successors(node):
                print("  succ={suc} typ={typ} e={e:.2f} eta={eta:.2f} w={w:.2f}".format(
                      suc=suc,
                      typ=g.nodes[suc]["typ"],
                      e=g.nodes[suc]["e"],
                      eta=g.nodes[suc]["eta"],
                      w=g.edges[(node, suc)]["weight"]))

# %%
node = ('pfcand', 701)
for pred in g.predecessors(node):
    print(pred, g.nodes[pred]["typ"], g.edges[(pred, node)]["weight"])
